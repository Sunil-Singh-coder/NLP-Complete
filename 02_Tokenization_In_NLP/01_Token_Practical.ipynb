# %%
# !pip install nltk

# %%
corpus= """ 
Hello I am sunil and i am self motivated and Hard working.
I always try to perform better every day so that my carrier will be good.
The girl's bag here
"""
print(corpurus)
# Out:
#
# Hello I am sunil and i am self motivated and Hard working.
# I always try to perform better every day so that my carrier will be good.
# The girl's bag here

# %%
# Tokenization  
# convert Sentenece ----->  paragraph 
from nltk.tokenize import sent_tokenize
import nltk
# nltk.download('punkt_tab')

# %%
sentences=sent_tokenize(corpus)
print(sentences)#  it just convert into list
# Out:
# [' \nHello I am sunil and i am self motivated and Hard working.', 'I always try to perform better every day so that my carrier will be good.', "The girl's bag here"]

# %%
for sentence in sentences:      #PRINT one by one sentence from corpus
    print(sentence)
# Out:
#
# Hello I am sunil and i am self motivated and Hard working.
# I always try to perform better every day so that my carrier will be good.
# The girl's bag here

# %%
# Tokenization 
# Sentence ------> Directly word      we use word_tokenize()
from nltk.tokenize import word_tokenize        # word_Tokenize is used to convert Paragraph into Words

# %%
word= word_tokenize(corpus)
print(word)     # i got words of paragpaph
# Out:
# ['Hello', 'I', 'am', 'sunil', 'and', 'i', 'am', 'self', 'motivated', 'and', 'Hard', 'working', '.', 'I', 'always', 'try', 'to', 'perform', 'better', 'every', 'day', 'so', 'that', 'my', 'carrier', 'will', 'be', 'good', '.', 'The', 'girl', "'s", 'bag', 'here']

# %%
for sentence in sentences:      # print one by one words from sentence of corpus
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'I', 'am', 'sunil', 'and', 'i', 'am', 'self', 'motivated', 'and', 'Hard', 'working', '.']
# ['I', 'always', 'try', 'to', 'perform', 'better', 'every', 'day', 'so', 'that', 'my', 'carrier', 'will', 'be', 'good', '.']
# ['The', 'girl', "'s", 'bag', 'here']

# %%
wordpunct_tokenize()  # it basically convert paragraph into words and it also separate 's but 
# in word tokenizer it do not do.

# %%
Treebankword_tokenize()   # it also convert Paragraph into word by considering only separate only last full stop
# and except last full stop it do not separate
